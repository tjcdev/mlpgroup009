# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # Baseline

# %% [markdown]
# #### Bipedal Walker (base-1)

# %%
base_bip = pd.read_json('base-bip-10m.json')
base_bip['code'] = 'base-1'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             ci="explained_variance",
             err_style="band",
             data=base_bip)
plt.ylim(-160, 300)
plt.show()
sns_plot.get_figure().savefig("baseline_normal.png",  bbox_inches = 'tight')

# %% [markdown]
# #### Biphard (base-2)

# %%
base_biphard = pd.read_json('base-biphard-10m.json')
base_biphard['code'] = 'base-2'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=base_biphard)
plt.ylim(-160, 50)
plt.show()

sns_plot.get_figure().savefig("baseline_hardcore.png",  bbox_inches = 'tight')

# %% [markdown]
# # Checks

# %% [markdown]
# #### Checking our transfer learning code actually works for the bip

# %%
check = pd.read_json('check-1.json')
check['code'] = 'check-1'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=check)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("check_normal.png",  bbox_inches = 'tight')

# %% [markdown]
# # Weight Sharing

# %% [markdown]
# ## All Layers

# %% [markdown]
# #### Bip with Biphard Weights (tl-1)

# %%
tl_bip = pd.read_json('tl-bip-with-biphard.json')
tl_bip['code'] = 'tl-1'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_bip)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("alllayers_normal_with_hardcore_weights.png",  bbox_inches = 'tight')

# %%
both = base_bip.append(tl_bip)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_all_layers_comp_normal.png",  bbox_inches = 'tight')

# %% [markdown]
# #### Biphard with Bip Weights (tl-3)

# %%
tl_biphard = pd.read_json('tl-biphard-with-bip.json')
tl_biphard['code'] = 'tl-3'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard)
plt.ylim(-160, 50)
plt.show()

sns_plot.get_figure().savefig("hardcore_with_normal_weights.png",  bbox_inches = 'tight')

# %%
both = base_biphard.append(tl_biphard)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_all_layers_comp_hardcore.png",  bbox_inches = 'tight')

# %% [markdown]
# ## 1st Layer Only

# %% [markdown]
# #### Bip with Biphard weights (tl-7)

# %%
tl_bip_first_layer_biphard = pd.read_json('tl-bip-with-first-layer-biphard.json')
tl_bip_first_layer_biphard['code'] = 'tl-7'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_bip_first_layer_biphard)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("1stlayer_normal_with_hardcore_weights.png",  bbox_inches = 'tight')

# %%
both = base_bip.append(tl_bip_first_layer_biphard)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_1stlayer_normal.png",  bbox_inches = 'tight')

# %% [markdown]
# #### Biphard with Bip weights (tl-9)

# %%
tl_biphard_first_layer_bip = pd.read_json('tl-biphard-with-first-layer-bip.json')
tl_biphard_first_layer_bip['code'] = 'tl-9'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard_first_layer_bip)
plt.ylim(-160, 50)
plt.show()

sns_plot.get_figure().savefig("1stlayer_hardcore_with_normal_weights.png",  bbox_inches = 'tight')

# %%
both = base_biphard.append(tl_biphard_first_layer_bip)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_1stlayer_hardcore_comp.png",  bbox_inches = 'tight')

# %% [markdown]
# ## All Layers with 1st Layer Locked

# %% [markdown]
# #### Bip with Biphard weights (TL-13)

# %%
tl_bip_locked_biphard = pd.read_json('tl-bip-with-locked-biphard.json')
tl_bip_locked_biphard['code'] = 'tl-13'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_bip_locked_biphard)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("alllayers_1stlocked_normal_with_hardcore_weights.png",  bbox_inches = 'tight')

# %%
both = base_bip.append(tl_bip_locked_biphard)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_alllayers_1stlocked_normal_with_hardcore_weights.png",  bbox_inches = 'tight')

# %% [markdown]
# #### Biphard with Bip weights (TL-14)

# %%
tl_biphard_locked_bip = pd.read_json('tl-biphard-with-locked-bip.json')
tl_biphard_locked_bip['code'] = 'tl-14'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard_locked_bip)
plt.ylim(-160, 50)
plt.show()

sns_plot.get_figure().savefig("alllayers_1stlocked_hardcore_with_normal_weights.png",  bbox_inches = 'tight')

# %%
both = base_biphard.append(tl_biphard_locked_bip)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_alllayers_1st_locked_hardcore.png",  bbox_inches = 'tight')

# %% [markdown]
# # Dillation(?)

# %%
dill = pd.read_json('dill.json')
dill['code'] = 'dill'
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             ci="explained_variance",
             err_style="band",
             data=dill)
plt.ylim(-160, 100)
plt.show()

sns_plot.get_figure().savefig("dilation.png",  bbox_inches = 'tight')

# %%
# Dilation bip baseline compare

both = base_bip.append(dill)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_dilation_normal.png",  bbox_inches = 'tight')

# %%
# Dilation biphard baseline compare

both = base_biphard.append(dill)
sns_plot = sns.lineplot(x="nupdates", y="eprewmean",
             hue='code',
             data=both)
plt.ylim(-160, 300)
plt.show()

sns_plot.get_figure().savefig("comp_dilation_hardcore.png",  bbox_inches = 'tight')
