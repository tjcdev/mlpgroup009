# %%
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# # Baseline

# %% [markdown]
# #### Bipedal Walker

# %%
base_bip = pd.read_json('base-bip.json')
sns.lineplot(x="nupdates", y="eprewmean", data=base_bip)

# %% [markdown]
# #### Bipedal Walker Hardcore

# %%
base_bip = pd.read_json('base-bip-hard.json')
sns.lineplot(x="nupdates", y="eprewmean", data=base_bip)

# %% [markdown]
# #### Lunar Lander

# %%
base_bip = pd.read_json('base-lun.json')
sns.lineplot(x="nupdates", y="eprewmean", data=base_bip)

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# #### Bipedal Walker using Bipedal Walker Hardcore Weights

# %%
tl_bip = pd.read_json('tl-bip-using-bip-hard-weights.json')
sns.lineplot(x="nupdates", y="eprewmean", data=tl_bip)

# %% [markdown]
# #### Bipedal Walker Hardcore using Bipedal Walker Weights

# %%
tl_biphard = pd.read_json('tl-bip-hard-using-bip-weights.json')
sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard)

# %% [markdown]
# # Transfer Learning for 1 Layer

# %% [markdown]
# #### Bip using Bip Hard weights

# %%
tl_biphard = pd.read_json('tl-1-layer-bip-using-bip-hard-weights.json')
sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard)

# %% [markdown]
# #### Biphard using Bip Weights

# %%
tl_biphard = pd.read_json('tl-1-layer-bip-hard-using-bip-weights.json')
sns.lineplot(x="nupdates", y="eprewmean", data=tl_biphard)

# %% [markdown]
# # Dillation?

# %%
dil = pd.read_json('consecutive-training.json')
sns.lineplot(x="nupdates", y="eprewmean", data=dil)

# %% [markdown]
# # 10M Timesteps - Baselines

# %% [markdown]
# #### Bip

# %%
dil = pd.read_json('base-bip-10m.json')
sns.lineplot(x="nupdates", y="eprewmean", data=dil)

# %% [markdown]
# #### Biphard

# %%
dil = pd.read_json('base-biphard-10m.json')
sns.lineplot(x="nupdates", y="eprewmean", data=dil)
